# %%
# Créatino d'un dataframe à partir de la structure d'un dictoinnaire

s1 = {'nom' : 'pandas', 'age': 26, 'taille' : [24, 53, 89]}

# %%
import pandas as pd

donnes = pandas.DataFrame(s1)
donnes
# Out:
#       nom  age  taille
# 0  pandas   26      24
# 1  pandas   26      53
# 2  pandas   26      89

# %%
donnes.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
donnes.set_index('taille')
# Out:
#            nom  age
# taille
# 24      pandas   26
# 53      pandas   26
# 89      pandas   26

# %%
#Lecture de fichier CSV

# %%
d1 = pd.read_csv('../../_git/donnees/meteo/2023/synop.202309.csv', sep=';')
d1.columns
d1.drop(columns=['Unnamed: 59'],inplace=True)
d1.head()
d1.replace('mq', 'NaN', inplace=True)
d1
# Out:
#        numer_sta            date    pmer tend cod_tend   dd         ff  \
# 0           7005  20230901000000  101120   10        2  230   1.700000
# 1           7015  20230901000000  101110    0        5  160   1.800000
# 2           7020  20230901000000  100950  -60        6  210   6.500000
# 3           7027  20230901000000  101150  -60        6  200   4.600000
# 4           7037  20230901000000  101220    0        0  250   4.700000
# ...          ...             ...     ...  ...      ...  ...        ...
# 14589      78925  20230930210000  100810  -30        6   60   2.400000
# 14590      81401  20230930210000  100780   10        5   60   1.800000
# 14591      81405  20230930210000  100880    0        5  100   3.700000
# 14592      81408  20230930210000  100840    0        5   90   3.600000
# 14593      89642  20230930210000   98690  100        3  140  13.900000
#
#                 t          td   u  ... hnuage1 nnuage2 ctype2 hnuage2 nnuage3  \
# ...

# %%
#Lecture de fichier CSV  

d2 = pd.read_csv('../../_git/donnees/AirQualityUCI01.csv', sep=',')
d2.drop(columns=['Unnamed: 15', 'Unnamed: 16'],inplace=True)
d2.fillna({
    'Date':'1/1/1900',
    'Time':00.00, 
    'CO(GT)': 0.0, 
    'PT08.S1(CO)' : 0.0, 
    'C6H6(GT)': 0.0, 
    'PT08.S2(NMHC)' : 0.0, 
    'NOx(GT)': 0.0, 
    'PT08.S3(NOx)' : 0.0,
    'NO2(GT)': 0.0,
    'PT08.S4(NO2)': 0.0,
    'PT08.S5(O3)' : 0.0,
    'T': 0.0,
    'RH': 0.0,
    'AH': 0.0
    
})
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466    1/1/1900       0.0     0.0          0.0       NaN       0.0
# 9467    1/1/1900       0.0     0.0          0.0       NaN       0.0
# 9468    1/1/1900       0.0     0.0          0.0       NaN       0.0
# 9469    1/1/1900       0.0     0.0          0.0       NaN       0.0
# 9470    1/1/1900       0.0     0.0          0.0       NaN       0.0
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...
