# %%
import pandas as pd
import os

# %%
os.chdir("C:/Users/etien/Documents/CCI/_HUB/cours/2024-2025/big_data/_git/donnees/ebrasil")
# !dir
# Out:
#  Le volume dans le lecteur C s’appelle Windows-SSD
#  Le numéro de série du volume est 84DC-AF7F
#
#  Répertoire de C:\Users\etien\Documents\CCI\_HUB\cours\2024-2025\big_data\_git\donnees\ebrasil
#
# 20/11/2024  16:30    <DIR>          .
# 20/11/2024  15:02    <DIR>          ..
# 06/10/2019  21:27         9 033 957 olist_customers_dataset.csv
# 06/10/2019  21:27        61 273 883 olist_geolocation_dataset.csv
# 06/10/2019  21:27        17 654 914 olist_orders_dataset.csv
# 06/10/2019  21:27        15 438 671 olist_order_items_dataset.csv
# 06/10/2019  21:27         5 777 138 olist_order_payments_dataset.csv
# 06/10/2019  21:27        14 409 007 olist_order_reviews_dataset.csv
# 06/10/2019  21:27         2 379 446 olist_products_dataset.csv
# 28/09/2020  08:52           177 799 olist_sellers_dataset.csv
# 12/11/2024  14:11             2 613 product_category_name_translation.csv
#                9 fichier(s)      126 147 428 octets
# ...

# %%
## importation des fichiers de donnees

# %%
products = pd.read_csv('olist_products_dataset.csv')
products_translated = pd.read_csv('product_category_name_translation.csv')
cat = pd.merge(products, products_translated, on="product_category_name")
cat = cat.drop(columns="product_category_name")

# %%
cat
# Out:
#                              product_id  product_name_lenght  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f                 44.0
# 2      96bd76ec8810374ed1b65e291975717f                 46.0
# 3      cef67bcfe19066a932b7673e239eb23d                 27.0
# 4      9dc1a7de274444849c219cff195d0b71                 37.0
# ...                                 ...                  ...
# 32323  a0b7d5a992ccda646f2d34e418fff5a0                 45.0
# 32324  bf4538d88321d0fd4412a93c974510e6                 41.0
# 32325  9a7c6041fa9592d9d9ef6cfe62a71f8c                 50.0
# 32326  83808703fc0706a22e264b9d75f04a2e                 60.0
# 32327  106392145fca363410d287a815be6de4                 58.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           287.0                 1.0             225.0
# 1                           276.0                 1.0            1000.0
# ...

# %% [markdown]
# ## Ajouter des traductions

# %%
def func(catName):

# %%
f = categories.map(func(x))
